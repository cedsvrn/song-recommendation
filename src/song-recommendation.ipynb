# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt

pd.set_option('display.max_columns', 100)

# %%
data = pd.read_csv('../input/spotify-12m-songs/tracks_features.csv')

# %%
data.head()

# %%
data.info()

# %%
data.describe()

# %%
data[data['year']==0]

# %%
# Taking off data with Year==0
print(data[data['year']==0]['year'].count())
data = data[data['year']!=0]

# %%
# fig, ax = plt.subplots()
sns.histplot(data=data, x="year", binwidth=3)
# ax.set_xlim(data['year'].min(), data['year'].max())
# plt.show()

# %%
from ast import literal_eval

def converter(x):
    #define format of datetime
    return literal_eval(x)

data['artists'] = data['artists'].apply(lambda x: converter(x))

# %%
data.info()
